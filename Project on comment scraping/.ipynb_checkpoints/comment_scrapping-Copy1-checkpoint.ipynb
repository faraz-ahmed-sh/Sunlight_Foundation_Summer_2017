# %%
# Assignment: Open Data Policies comments scrape

import re
import util
import bs4
import queue
import json
import sys
import csv
import urllib
import collections
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import nltk
from nltk.book import *
import distance
import jellyfish
import sys
#nltk.download()
from nltk.corpus import stopwords
#from nltk.sentiment.vader import SentimentIntensityAnalyzer
#from nltk import tokenize
#from textblob import TextBlob
#from textblob import TextBlob
#textblob.download()

# %%
stop = set(stopwords.words('english'))
stop.update(['-', '&', "'s", '.', ',', '"', "'", '?', '!', ':', ';', '(', ')', '[', ']', '{', '}', '.', 'the', ',', 'and', 'of', ';', 'for', 'that', 'on', 'to', 'a', 'or', 'is', 'in', '’', '"', '”', "" ])

# %%
starting_urls_list = ["https://mymadison.io/documents/city-of-buffalo-open-data-policy", 
                      "https://mymadison.io/documents/durham-open-data-policy",
                      "https://mymadison.io/documents/city-of-tyler-data-policy",
                      "https://mymadison.io/documents/city-of-glendale-draft-open-data-resolution",
                      "https://mymadison.io/documents/metro-nashville-government-open-data-policy",
                      "https://mymadison.io/documents/city-of-syracuse-open-data-policy",
                      "https://mymadison.io/documents/napervilleopendatapolicy",
                      "https://mymadison.io/documents/bart-open-data-policy",
                      "https://mymadison.io/documents/san-francisco-open-data-legislation-2014"]

# %%
starting_url = "https://mymadison.io/documents/city-of-buffalo-open-data-policy?comment_page=1"

# %% [markdown]
# ## Auxillary functions

# %%
def simple_crawl(starting_url):
    '''
    Scrapes the full webpage from a starting url.

    Inputs:
        starting_url: string
    Returns:
        a soup object
    '''    
    page = urllib.request.urlopen(starting_url)
    if page is not None:
        soup = bs4.BeautifulSoup(page, "html")
        return soup

# %%
def comment_id(comment):
    comment_id = comment.get('id')
    return comment_id

# %%
def name(comment):
    name_date = comment.find("div", class_="media-body media-middle")
    name = name_date.find("span")
    name_final = name.string.strip()
    return name_final, name_date

# %%
def datetime(comment):
    name_date = name(comment)[1]
    time = name_date.find("time")
    datetime_final = time.get("datetime")[:-6]
    datetime_final_1 = datetime_final.replace("T", " ")
    return datetime_final_1

# %%
def likes_count(comment):
    name_date = name(comment)[1]
    likes = name_date.find("span", class_="action-count")
    return likes.string.strip()

# %%
def quoted_comment(comment):
    comments = comment.find("div", class_="comment-content")
    quoted_comment = comments.find("blockquote")
    if quoted_comment is not None:
        quoted_comment_final = quoted_comment.text.strip()
        return quoted_comment_final, comments
    else:
        return None, comments

# %%
def actual_comment(comment):
    comments = comment.find("div", class_="comment-content")
    actual_comments = comments.find_all("p", recursive=False)
    
    complete_str_aux = ''
    complete_str_str = ''
    
    for child in actual_comments:
        complete_str_aux += str(child)
        complete_str_str += str(child.text)
    return complete_str_aux, complete_str_str

# %%
def reply_ids(comment):
    
    replies = comment.find_all("div", class_="comment")
    if replies is not None:
        reply_id_list = []
        for reply in replies:
            reply_id=reply.get('id')
            reply_id_list.append(reply_id)

        return reply_id_list
    else:
        return []

# %%
def find_total_num_pages(starting_url):
    soup = simple_crawl(starting_url)
    next_page = soup.find_all("ul", class_="pagination")
    
    for page in next_page:
        pages = page.find_all("a")
        total_num_pages = pages[-2].get("href")
        return int(total_num_pages[-1])

# %%
def calling_functions(commentators, comments_dictionary, comment_number):
    
    for comment in commentators:
        
        comment_id_f = comment_id(comment)
        name_f =  name(comment)
        timedate_f = datetime(comment)
        likes_count_f = likes_count(comment)
        quoted_comment_f = quoted_comment(comment)
        actual_comment_f, actual_comment_str =  actual_comment(comment)
        reply_ids_f = reply_ids(comment)


        comments_dictionary[comment_number] = [comment_id_f,name_f[0], timedate_f, 
                                      likes_count_f, quoted_comment_f[0],
                                       actual_comment_str, actual_comment_f, reply_ids_f]
        comment_number += 1
    
    return comments_dictionary, comment_number

# %% [markdown]
# ## Function to scrape a particular open data policy

# %%
def scrape_all_pages(starting_url):
    '''
    This functions scrapes the required data from all the webpages for a PARTICULAR starting url of a Madison webpage.
    '''
    comments_dictionary = {}
    num_pages_to_crawl = find_total_num_pages(starting_url)
    
    if num_pages_to_crawl is None:
        num_pages_to_crawl = 1
        
    loop_number = 0
    comment_number = 1

    while loop_number < num_pages_to_crawl:
    
        soup = simple_crawl(starting_url)
        commentators = soup.findAll("li", class_="comment floating-card")
        
        comments_dictionary, comment_number = calling_functions(commentators, comments_dictionary, comment_number)
        
        next_page = soup.find_all("ul", class_="pagination")
        for page in next_page:
            pages = page.find_all("a")
            starting_url = pages[-1].get("href")
        
        loop_number += 1
        
    return comments_dictionary

# %%
comments_dictionary = scrape_all_pages(starting_url)
# Out:
# /Users/summerfellow/anaconda/envs/py35/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/summerfellow/anaconda/envs/py35/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "html.parser")
#
#   markup_type=markup_type))

# %%
def convert_dict_pandas(comments_dictionary):
    
    df = pd.DataFrame(comments_dictionary)
    df = df.transpose()
    df.columns = ['comment_id', 'author', 'datetime', 'num_likes', 'quoted_text', 'comment_text', 'comment_text_aux', 'reply_ids']
    
    # converting str datetime into datetime pandas format
    df['datetime'] = pd.to_datetime(df['datetime'])
    return df

# %%
convert_dict_pandas(comments_dictionary).head()
# Out:
#     comment_id             author            datetime num_likes  \
# 1  E4-XFnl1uKc          Aaron Lee 2017-01-25 04:32:19         2
# 2  E4-XFnjG3Ac          Aaron Lee 2017-01-25 04:25:20         0
# 3  E4-XFnQhy2g  Aaron Krolikowski 2017-01-24 22:56:17         3
# 4  E4-XFnNQNY8  Aaron Krolikowski 2017-01-24 22:46:57         0
# 5  E4-XFnJHPCA  Aaron Krolikowski 2017-01-24 22:45:58         0
#
#                                          quoted_text  \
# 1                                               None
# 2  public participation by providing regular oppo...
# 3                                               None
# 4  Publish high quality, updated data with docume...
# 5  limitations on the disclosure of public inform...
#
#                                         comment_text  \
# 1  I am in support of the proposed policy to furt...
# 2  I would be interested to see this more finely ...
# 3  I strongly support the proposed policy, with a...
# 4  Can the portal include an option for community...
# 5  It may be a helpful option to include a reposi...
#
#                                     comment_text_aux reply_ids
# 1  <p>I am in support of the proposed policy to f...        []
# 2  <p>I would be interested to see this more fine...        []
# 3  <p>I strongly support the proposed policy, wit...        []
# 4  <p>Can the portal include an option for commun...        []
# 5  <p>It may be a helpful option to include a rep...        []

# %%
temp = convert_dict_pandas(comments_dictionary)

# %%
# temp['quoted_text'].dropna().map(lambda y: y.replace('<p>','').replace('</p>','')).apply(lambda x: pd.Series(x).value_counts()).sum()
temp['quoted_text'].dropna().apply(lambda x: pd.Series(x.lower().split()).value_counts()).sum().sort_values(ascending=False).head()
# Out:
# the     27.0
# and     22.0
# data    20.0
# of      16.0
# for     10.0
# dtype: float64

# %% [markdown]
# ## scrape all the open data policy comments

# %%
def go_all_madison_websites(starting_urls_list):
    '''
    This function scrapes the comments from all the Madison related webistes for cities that have
    launched open data policies and converts them into pandas dataframe objects.
    
    Returns:
        DataFrame object for each city's open data policy.
    '''
    
    all_madison_websites_dfs = []
    all_cities_dataframe = pd.DataFrame()
    for starting_url in starting_urls_list:
        #print(starting_url)
        comments_dictionary = scrape_all_pages(starting_url)
        get_dict_to_pandas = convert_dict_pandas(comments_dictionary)
        relative_url = starting_url.split('/')[-1]
        all_madison_websites_dfs.append((relative_url, get_dict_to_pandas))
        all_cities_dataframe = all_cities_dataframe.append(get_dict_to_pandas)
        
    return all_madison_websites_dfs, all_cities_dataframe

# %%
all_madison_dfs, all_cities_dataframe = go_all_madison_websites(starting_urls_list)
# Out:
# /Users/summerfellow/anaconda/envs/py35/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/summerfellow/anaconda/envs/py35/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "html.parser")
#
#   markup_type=markup_type))

# %%
all_cities_dataframe.head()
# Out:
#     comment_id             author            datetime num_likes  \
# 1  E4-XFnl1uKc          Aaron Lee 2017-01-25 04:32:19         2
# 2  E4-XFnjG3Ac          Aaron Lee 2017-01-25 04:25:20         0
# 3  E4-XFnQhy2g  Aaron Krolikowski 2017-01-24 22:56:17         3
# 4  E4-XFnNQNY8  Aaron Krolikowski 2017-01-24 22:46:57         0
# 5  E4-XFnJHPCA  Aaron Krolikowski 2017-01-24 22:45:58         0
#
#                                          quoted_text  \
# 1                                               None
# 2  public participation by providing regular oppo...
# 3                                               None
# 4  Publish high quality, updated data with docume...
# 5  limitations on the disclosure of public inform...
#
#                                         comment_text  \
# 1  I am in support of the proposed policy to furt...
# 2  I would be interested to see this more finely ...
# 3  I strongly support the proposed policy, with a...
# 4  Can the portal include an option for community...
# 5  It may be a helpful option to include a reposi...
#
#                                     comment_text_aux reply_ids
# 1  <p>I am in support of the proposed policy to f...        []
# 2  <p>I would be interested to see this more fine...        []
# 3  <p>I strongly support the proposed policy, wit...        []
# 4  <p>Can the portal include an option for commun...        []
# 5  <p>It may be a helpful option to include a rep...        []

# %%
for name, city in all_madison_dfs:
    print(name)
# Out:
# city-of-buffalo-open-data-policy
# durham-open-data-policy
# city-of-tyler-data-policy
# city-of-glendale-draft-open-data-resolution
# metro-nashville-government-open-data-policy
# city-of-syracuse-open-data-policy
# napervilleopendatapolicy
# bart-open-data-policy
# san-francisco-open-data-legislation-2014

# %% [markdown]
# # Analysis of comments

# %% [markdown]
# ## 1) finding out most common words in quoted texts (policy sections) and actual comments

# %% [markdown]
# ### -most common words in quoted texts

# %%
def common_words_quoted_texts(type_of_text, city_name, city_dictionary, common_words_limit):
    string_quoted_text = city_dictionary[type_of_text].str.cat(sep=' ').lower()
    words = nltk.tokenize.word_tokenize(string_quoted_text)
    good_words = [i for i in words if i not in stop] # stop words
    fdist = FreqDist(good_words)
    common_quoted_text_20 = fdist.most_common(common_words_limit)
    df = pd.DataFrame(data=common_quoted_text_20, columns=['word', 'count'])
    return df, fdist.plot(common_words_limit, title=city_name)

# %% [markdown]
# ### for each city

# %%
for name, dictionary in all_madison_dfs:
    #print(name)
    print(common_words_quoted_texts('quoted_text', name, dictionary, 20))
# Out:
# (           word  count
# 0          data     20
# 1          open     10
# 2        public      7
# 3          city      5
# 4      datasets      4
# 5   information      4
# 6     committee      4
# 7    governance      4
# 8       records      3
# 9    government      3
# 10    residents      3
# 11       ensure      3
# 12       policy      3
# 13      develop      3
# 14          use      3
# 15    protected      2
# 16        reuse      2
# 17        needs      2
# 18        media      2
# 19      process      2, None)
# (Empty DataFrame
# Columns: [word, count]
# Index: [], None)
# (Empty DataFrame
# Columns: [word, count]
# Index: [], None)
# (          word  count
# 0     location      1
# 1      website      1
# 2  centralized      1
# 3         city      1, None)
# (           word  count
# 0      drawings      1
# 1     documents      1
# 2        copies      1
# 3   information      1
# 4        freely      1
# 5        proper      1
# 6    respecting      1
# 7        credit      1
# 8      datasets      1
# 9      original      1
# 10   agreements      1
# 11    available      1
# 12      scanned      1
# 13    protected      1
# 14     maintain      1
# 15     security      1
# 16      privacy      1
# 17       office      1
# 18        shall      1
# 19        mayor      1, None)
# (             word  count
# 0            data     15
# 1            city      9
# 2     information      8
# 3          public      7
# 4            open      6
# 5          agency      5
# 6        datasets      4
# 7       sensitive      4
# 8       published      4
# 9         dataset      3
# 10         policy      3
# 11          means      3
# 12    publishable      3
# 13      protected      3
# 14       archives      2
# 15  participation      2
# 16        publish      2
# 17              “      2
# 18      available      2
# 19     historical      2, None)
# (             word  count
# 0            data     13
# 1            open      9
# 2            city      7
# 3          public      6
# 4      department      3
# 5      publishing      3
# 6     information      3
# 7         license      3
# 8           basis      3
# 9         created      2
# 10              -      2
# 11         placed      2
# 12       datasets      2
# 13   distribution      2
# 14           said      2
# 15  participation      2
# 16         behalf      2
# 17    statistical      2
# 18   quantitative      2
# 19             --      2, None)
# (Empty DataFrame
# Columns: [word, count]
# Index: [], None)
# (             word  count
# 0  administrative      1
# 1       timelines      1
# 2            data      1
# 3    transparency      1
# 4       releasing      1
# 5            code      1
# 6      procedures      1
# 7               -      1
# 8            open      1, None)

# %% [markdown]
# ### for all the cities combined

# %%
common_words_quoted_texts("quoted_text", "All cities", all_cities_dataframe, 20)
# Out:
# (             word  count
#  0            data     49
#  1            open     27
#  2            city     22
#  3          public     20
#  4     information     16
#  5        datasets     11
#  6       published      8
#  7          policy      7
#  8       protected      7
#  9          agency      6
#  10      sensitive      6
#  11      including      5
#  12         ensure      5
#  13  participation      5
#  14      committee      5
#  15        dataset      5
#  16     governance      5
#  17            new      5
#  18         behalf      4
#  19      available      4, None)

# %% [markdown]
# ## 2) finding out most common words in actual comments

# %%
for name, dictionary in all_madison_dfs:
    #print(name)
    print(common_words_quoted_texts('comment_text', name, dictionary, 30))
# Out:
# (            word  count
# 0           data    111
# 1           open     51
# 2           city     48
# 3         public     41
# 4        buffalo     34
# 5    information     26
# 6          would     19
# 7         policy     18
# 8         portal     14
# 9      community     14
# 10        access     13
# 11    government     13
# 12      document     11
# 13     residents     11
# 14          also     11
# 15       support     11
# 16      requests     10
# 17  transparency     10
# 18       include     10
# 19     committee     10
# 20       comment      9
# 21       process      9
# 22           use      9
# 23           pai      9
# 24     available      9
# 25       members      8
# 26    governance      8
# 27          make      8
# 28      comments      8
# 29          made      8, None)
# (            word  count
# 0          seems      2
# 1            hit      1
# 2       possible      1
# 3         really      1
# 4          quick      1
# 5           good      1
# 6         points      1
# 7   read-through      1
# 8           mind      1
# 9          occur      1
# 10  improvements      1
# 11          come      1
# 12         right      1
# 13         major      1, None)
# (            word  count
# 0           data      4
# 1             ``      3
# 2          goals      3
# 3             ''      3
# 4       requests      2
# 5         person      2
# 6       consider      2
# 7          hours      2
# 8         policy      2
# 9        project      2
# 10          foia      2
# 11      timeline      2
# 12          want      2
# 13         clear      1
# 14        hurdle      1
# 15    identified      1
# 16           end      1
# 17   information      1
# 18      response      1
# 19          item      1
# 20       dispute      1
# 21   identifying      1
# 22          soon      1
# 23  professional      1
# 24     including      1
# 25      openness      1
# 26       without      1
# 27         going      1
# 28        office      1
# 29      clerical      1, None)
# (            word  count
# 0    information      7
# 1           data      6
# 2     resolution      4
# 3           city      4
# 4          needs      3
# 5        website      3
# 6       glendale      3
# 7       comments      3
# 8   transparency      3
# 9        citizen      3
# 10         would      3
# 11       process      2
# 12       council      2
# 13       special      2
# 14       support      2
# 15          find      2
# 16         value      2
# 17      feedback      2
# 18             &      2
# 19            ''      2
# 20          easy      2
# 21        thanks      2
# 22    commission      2
# 23          open      2
# 24        posted      2
# 25         serve      2
# 26       someone      2
# 27            ``      2
# 28       already      2
# 29         great      2, None)
# (                                                 word  count
# 0                                         attribution      7
# 1                                             section      4
# 2                                          government      4
# 3                                                  ``      4
# 4                                                data      4
# 5                                               metro      3
# 6                                          acceptable      3
# 7                                                 say      3
# 8                                                item      2
# 9                                            metadata      2
# 10                                                 ''      2
# 11                                               open      2
# 12                                           davidson      2
# 13                                                  4      2
# 14                                                 's      2
# 15                                              given      2
# 16                                             county      2
# 17                                              https      2
# 18                                               idea      2
# 19                                                 ix      2
# 20                                                use      2
# 21                                             credit      2
# 22                                      'metropolitan      2
# 23                                          nashville      2
# 24                                              would      2
# 25                                             street      1
# 26                                          direction      1
# 27  //data.nashville.gov/beautification/metro-wate...      1
# 28                                            greater      1
# 29                                                  -      1, None)
# (           word  count
# 0          data     41
# 1            ''     28
# 2            ``     28
# 3             &     17
# 4        policy     14
# 5       process     12
# 6         would     11
# 7          open     11
# 8             -     10
# 9          city     10
# 10      defined      9
# 11      believe      8
# 12    processes      6
# 13          ...      6
# 14      clearly      6
# 15      support      6
# 16   initiative      6
# 17      program      6
# 18         e.g.      5
# 19          set      5
# 20       public      5
# 21            1      5
# 22         also      5
# 23  information      5
# 24         want      5
# 25      dataset      5
# 26     document      4
# 27          way      4
# 28    important      4
# 29           'd      4, None)
# (             word  count
# 0            data     18
# 1            city      9
# 2            open      8
# 3           would      8
# 4           great      7
# 5          public      6
# 6              ''      5
# 7            like      5
# 8              's      5
# 9              ``      5
# 10           make      5
# 11              -      4
# 12  collaboration      4
# 13         policy      4
# 14   transparency      4
# 15            key      4
# 16         format      3
# 17       feedback      3
# 18      important      3
# 19     challenges      3
# 20          could      3
# 21           laws      3
# 22          legal      3
# 23        include      3
# 24       language      3
# 25            api      3
# 26            may      3
# 27     naperville      3
# 28          codes      3
# 29         report      3, None)
# (          word  count
# 0         open     14
# 1           ''     11
# 2         data     11
# 3           ``      9
# 4       source      8
# 5         code      4
# 6      without      4
# 7   definition      4
# 8        least      3
# 9    solutions      3
# 10     license      3
# 11          'd      3
# 12         n't      3
# 13       apply      2
# 14  definitely      2
# 15       legal      2
# 16       reuse      2
# 17  government      2
# 18         ask      2
# 19        also      2
# 20      almost      2
# 21        bart      2
# 22      employ      2
# 23         cc0      2
# 24      public      2
# 25        know      2
# 26        good      2
# 27     m-13-13      2
# 28        owns      2
# 29    actually      2, None)
# (             word  count
# 0  administrative      1
# 1       timelines      1
# 2            data      1
# 3             lol      1
# 4       releasing      1
# 5            code      1
# 6      procedures      1
# 7               -      1
# 8            open      1, None)

# %% [markdown]
# ### for all the cities combined

# %%
common_words_quoted_texts("comment_text", "All cities", all_cities_dataframe, 20)
# Out:
# (            word  count
#  0           data    196
#  1           open     89
#  2           city     72
#  3             ''     58
#  4             ``     58
#  5         public     56
#  6          would     44
#  7    information     43
#  8         policy     40
#  9        buffalo     34
#  10       process     25
#  11    government     22
#  12  transparency     21
#  13       support     20
#  14      document     19
#  15     community     19
#  16          also     19
#  17       include     18
#  18        access     17
#  19        portal     16, None)

# %%
#least_popular_words

# %% [markdown]
# ## 2) finding out most common quoted text n-grams

# %% [markdown]
# ### method 1

# %%
string_quoted_text_list = temp['quoted_text'].dropna().tolist()

# %% [markdown]
# #### sample

# %%
from nltk.util import ngrams
from collections import Counter

def extract_phrases(string_quoted, length):
    phrase_counter = Counter()
    for sentence in string_quoted:
        non_speaker = re.compile('[A-Za-z]+: (.*)')
        for sent in nltk.sent_tokenize(sentence):
            strip_speaker = non_speaker.match(sent)
            if strip_speaker is not None:
                sent = strip_speaker.group(1)
            words = nltk.word_tokenize(sent)
            for phrase in ngrams(words, length):
                phrase_counter[phrase] += 1
    
        #extract_phrases(sentence, phrase_counter, 3)
    most_common_phrases = phrase_counter.most_common(15)
    
    most_common_phrases_new = []
    
    for k,v in most_common_phrases:
        #print ('{0: <5}'.format(v), k)
        p = ' '.join(k)
        #print(k)
        most_common_phrases_new.append((p, v))
    
    return most_common_phrases_new

# now do a jaro wrinkler score to bring the text together

# %%
string_quoted_text_list_1 = extract_phrases(string_quoted_text_list, 4) # sample

# %%
def top_policy_sections_commented(type_of_data, option, length):
    
    if type(type_of_data) == list: #if its a list of dictionaries of all the cities
        
        for name, dictionary in type_of_data:
            if option == "most_common_policy": # if the option is to find out comments of popular sections of each city
                list_of_lists_sentences = list_of_lists_of_sentences(name, dictionary, length)
                
                if len(list_of_lists_sentences) != 0: # don't print results for cities with no comments. (???)
                    sentiment_analysis_list = sentiment_analysis(list_of_lists_sentences, name, dictionary)
                    
            else:
                string_quoted_text_list = dictionary['comment_text'].dropna().tolist()
                sentiment_analysis_list = sentiment_analysis(string_quoted_text_list, name, dictionary)
 
            sentimental_analysis_graphs = sentimental_analysis_charts(sentiment_analysis_list)   
            print (sentimental_analysis_graphs)
                
    else: # it its one big dictionary containing data for all the cities
        name = "All Cities"
        
        if option == "most_common_policy": # if the option is to find out comments of popular sections
            list_of_lists_sentences = list_of_lists_of_sentences(name, type_of_data, length)
            sentiment_analysis_list = sentiment_analysis(list_of_lists_sentences, name, all_cities_dataframe)
        
        else: # if the option is to find out all the comments of all policy sections
            string_quoted_text_list = all_cities_dataframe['comment_text'].dropna().tolist()
            sentiment_analysis_list = sentiment_analysis(string_quoted_text_list, name, all_cities_dataframe)
            
        sentimental_analysis_graphs = sentimental_analysis_charts(sentiment_analysis_list)   
        print (sentimental_analysis_graphs)

# %%
def list_of_lists_of_sentences(name, dictionary, length):
    
    string_quoted_text_list = dictionary['quoted_text'].dropna().tolist()
    most_common_phrases = extract_phrases(string_quoted_text_list, length)
    print(name)
    print()
    for k,v in most_common_phrases:
        print(k,v)
    list_of_lists_sentences, city_name = most_common_phrases_to_list(name, dictionary, most_common_phrases)
    return list_of_lists_sentences

# %% [markdown]
# ### calculating jaro wrinkler scores to put the same policy sections with each other

# %%
filtered_most_common_phrases = []

common_dict = {}
for phrase, counter in most_common_phrases:
    full_length = ' '.join(phrase)
    common_dict[full_length] = [(full_length, counter)]
    
       
    for i, k in most_common_phrases:
        i = ' '.join(i)
        distance_score = jellyfish.jaro_distance(full_length, i) #filtered_most_common_phrases[-1][0][0] 


        if distance_score > 0.65 and distance_score < 1.0:
            if full_length in common_dict:
                
                common_dict[full_length].append((i,k))
                break
            
    else:
        common_dict[full_length] = [(full_length, counter)]
        break

    continue

result = {}

for key,value in common_dict.items():
    if len(value) > 1:
        if value[1][0] not in result:
            #print(value[1][0])
            result[key] = value
    else:
        result[key] = value
    
print (result)
# Out:
# {'the Open Data': [('the Open Data', 4), ('the public .', 2)], 'Open Data Governance': [('Open Data Governance', 4), ('Data Governance Committee', 4)], 'leaders , businesses': [('leaders , businesses', 2)], 'from the public': [('from the public', 3), ('the public .', 2)]}

# %% [markdown]
# ### finding out negative and positive sentiments for popular policy sections

# %%
def most_common_phrases_to_list(city_name, city_dictionary, most_common_phrases):
    
    list_of_lists_sentences = []
    for string_phrase, len_string_phrase in most_common_phrases:
        #print(string_phrase)
        #print(city_dictionary)
        actual_comment_filter = city_dictionary[city_dictionary['quoted_text'].astype(str).str.contains(string_phrase)]
        #print(actual_comment_filter)
        comment_list_sentiment = actual_comment_filter['comment_text'].tolist()
        list_of_lists_sentences.append(comment_list_sentiment)

    return (list_of_lists_sentences, city_name)

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

from nltk import tokenize

def sentiment_scores(sentence_list, city_dictionary, total_sentence_count, neg_count, neg_polarity, neu_count, neu_polarity, pos_count, pos_polarity):
    sid = SentimentIntensityAnalyzer()
    #print(sentence_list)
    for sentence in sentence_list:
        #print(sentence)
        ss = sid.polarity_scores(sentence)
        for k in sorted(ss):
            #print('{0}: {1}, '.format(k, ss[k]), end='')
            #print()
            if k == 'neg' and ss[k] >= 0.4:
                neg_count += 1
                neg_polarity += ss[k]
            elif k == 'neu' and ss[k] >= 0.7:
                neu_count += 1
                neu_polarity += ss[k]
            elif k == 'pos' and ss[k] >= 0.4:
                pos_count += 1
                pos_polarity += ss[k]
                #actual_comment_filter = city_dictionary[city_dictionary['comment_text'].astype(str).str.contains(sentence)]
                #actual_comment_filter_2 = actual_comment_filter['quoted_text'].to_string()
                #print("quoted policy", actual_comment_filter_2)
                print("positive sentence:", sentence)

        total_sentence_count += 1
    return total_sentence_count, neg_count, neg_polarity, neu_count, neu_polarity, pos_count, pos_polarity

# %%
def sentiment_analysis(list_of_lists_of_sentences, city_name, dictionary):
    #sid = SentimentIntensityAnalyzer()

    neg_count = 0
    neu_count = 0
    pos_count = 0
    neg_polarity = 0
    neu_polarity = 0
    pos_polarity = 0
    
    total_sentence_count = 0
    
    #print(list_of_lists_of_sentences)
    
    if type(list_of_lists_of_sentences[0]) == list:
        for sentence_list in list_of_lists_of_sentences:
            total_sentence_count, neg_count, neg_polarity, neu_count, neu_polarity, pos_count, pos_polarity = sentiment_scores(sentence_list, dictionary, total_sentence_count, neg_count, neg_polarity, neu_count, neu_polarity, pos_count, pos_polarity)
            
    else:
        total_sentence_count, neg_count, neg_polarity, neu_count, neu_polarity, pos_count, pos_polarity = sentiment_scores(list_of_lists_of_sentences, dictionary, total_sentence_count, neg_count, neg_polarity, neu_count, neu_polarity, pos_count, pos_polarity)
            
    #all_sentences = len(list_of_sentences)
    print()
    print("total_comments:", total_sentence_count, "----", "city name:", city_name)
    if total_sentence_count == 0:
        total_sentence_count = 1
    
    avg_neg_polarity = neg_polarity/total_sentence_count
    avg_neu_polarity = neu_polarity/total_sentence_count
    avg_pos_polarity = pos_polarity/total_sentence_count
                
    return ["neg count:", neg_count, "neu_count:", neu_count, "pos_count:", pos_count, "avg_neg_polarity:", avg_neg_polarity, "avg_neu_polarity:", avg_neu_polarity, "avg_pos_polarity:", avg_pos_polarity, "city_name", city_name]

# %%
def sentimental_analysis_charts(list_):
    
    #chart 1: for the count of comments
    x_objects = [i for i in list_[:6] if type(i) == str]
    y_pos = np.arange(len(x_objects))
    y_objects = [i for i in list_[:6] if type(i) == int]

    plt.bar(y_pos, y_objects, align='center', alpha=0.7, color="green")
    plt.xticks(y_pos, x_objects)
    plt.ylabel('Count of comments')
    plt.title('Sentiment Analysis Count' + " " + list_[-1])
    plt.show()
    
    #chart 2 for the average polarity of comments
    x_objects = [i for i in list_[6:-2] if type(i) == str]
    y_pos = np.arange(len(x_objects))
    y_objects = [i for i in list_[6:-2] if type(i) == float]

    plt.bar(y_pos, y_objects, align='center', alpha=0.7)
    plt.xticks(y_pos, x_objects)
    plt.ylim(0, 1)
    plt.ylabel('Average polarity of comments')
    plt.title('Sentiment Analysis Averages' + " " + list_[-1])
    plt.show()

# %% [markdown]
# ### sentiment analysis for each city for most common comments

# %%
sentimental_analysis_graphs = top_policy_sections_commented(all_madison_dfs, "most_common_policy", 4)
# Out:
# city-of-buffalo-open-data-policy
#
# Open Data Governance Committee 4
# the Open Data Governance 2
# a process for prioritizing 2
# Develop and implement a 2
# on internal and external 2
# will include input from 2
# implement a process for 2
# the release of datasets 2
# data based on internal 2
# , government leaders , 2
# internal and external needs 2
# update the data based 2
# periodically update the data 2
# government leaders , businesses 2
# prioritizing the release of 2
#
# total_comments: 26 ---- city name: city-of-buffalo-open-data-policy
# None
# durham-open-data-policy
# None
# city-of-tyler-data-policy
# None
# city-of-glendale-draft-open-data-resolution
#
# location on the city 1
# In a centralized location 1
# on the city website 1
# a centralized location on 1
# the city website ; 1
# centralized location on the 1
#
# total_comments: 5 ---- city name: city-of-glendale-draft-open-data-resolution
# None
# metro-nashville-government-open-data-policy
#
# Datasets that are open 1
# available while respecting the 1
# the privacy and security 1
# with external partners to 1
# be given or included 1
# publish and maintain Datasets 1
# copies of original documents 1
# or scanned copies of 1
# ITS and the Office 1
# such as designs , 1
# files , such as 1
# to publish and maintain 1
# as designs , drawings 1
# that are open and 1
# nor image files , 1
# positive sentence: Awesome!
# positive sentence: Awesome!
# positive sentence: Awesome!
# positive sentence: Awesome!
# positive sentence: Awesome!
# positive sentence: Cheers for this!
# positive sentence: Cheers for this!
# positive sentence: Awesome!
# positive sentence: Awesome!
# positive sentence: Awesome!
#
# total_comments: 11 ---- city name: metro-nashville-government-open-data-policy
# None
# city-of-syracuse-open-data-policy
#
# the city ’ s 3
# and sensitive information ; 2
# all publishable city data 2
# protected and sensitive information 2
# information ” means any 2
# , could raise privacy 1
# security concerns or have 1
# or portion thereof to 1
# an extent that is 1
# to make a determination 1
# have the potential to 1
# Central Online Location for 1
# York State ’ s 1
# a dataset may be 1
# processed by a computer 1
#
# total_comments: 13 ---- city name: city-of-syracuse-open-data-policy
# None
# napervilleopendatapolicy
#
# that is regularly maintained 2
# on an open license 2
# copying , further distribution 2
# , further distribution , 2
# with no restrictions on 2
# quantitative , or qualitative 2
# behalf of the City 2
# be placed into the 2
# factual , quantitative , 2
# , quantitative , or 2
# Data - Statistical , 2
# data will be placed 2
# of said data . 2
# , or qualitative information 2
# basis with no restrictions 2
#
# total_comments: 16 ---- city name: napervilleopendatapolicy
# None
# bart-open-data-policy
# None
# san-francisco-open-data-legislation-2014
#
# Code - Timelines and 1
# Timelines and Procedures for 1
# and Procedures for Releasing 1
# for Releasing Open Data 1
# Administrative Code - Timelines 1
# - Timelines and Procedures 1
# Procedures for Releasing Open 1
#
# total_comments: 7 ---- city name: san-francisco-open-data-legislation-2014
# None

# %% [markdown]
# ### sentiment analysis for each city for all comments

# %%
sentimental_analy`sis_graphs = top_policy_sections_commented(all_madison_dfs, "all_common_comments", 4)
# Out:
# positive sentence: this is amazing. Very important.
# positive sentence: protected information
# positive sentence: That would be super helpful :)
#
# total_comments: 66 ---- city name: city-of-buffalo-open-data-policy
# None
#
# total_comments: 1 ---- city name: durham-open-data-policy
# None
#
# total_comments: 4 ---- city name: city-of-tyler-data-policy
# None
#
# total_comments: 10 ---- city name: city-of-glendale-draft-open-data-resolution
# None
# positive sentence: Awesome!
# positive sentence: Cheers for this!
#
# total_comments: 6 ---- city name: metro-nashville-government-open-data-policy
# None
# positive sentence: YES
#
# total_comments: 50 ---- city name: city-of-syracuse-open-data-policy
# None
# positive sentence: Datasets should also be analyzed and improved to be customer friendly.
#
# total_comments: 24 ---- city name: napervilleopendatapolicy
# None
#
# total_comments: 1 ---- city name: bart-open-data-policy
# None
# positive sentence: LOL
#
# total_comments: 2 ---- city name: san-francisco-open-data-legislation-2014
# None

# %% [markdown]
# ### sentiment analysis for all the cities for most common comments

# %%
sentimental_analysis_graphs = top_policy_sections_commented(all_cities_dataframe, "most_common_policy", 4)
# Out:
# All Cities
#
# Open Data Governance Committee 5
# protected and sensitive information 4
# and implement a process 3
# and sensitive information ; 3
# Develop and implement a 3
# implement a process for 3
# the Open Data Governance 3
# the city ’ s 3
# copying , further distribution 2
# datasets are available for 2
# on use or reuse 2
# , further distribution , 2
# with no restrictions on 2
# appropriately safeguarding protected and 2
# factual , quantitative , 2
# positive sentence: Datasets should also be analyzed and improved to be customer friendly.
#
# total_comments: 27 ---- city name: All Cities
# None

# %% [markdown]
# ### sentiment analysis for all the cities for all comments

# %%
sentimental_analysis_graphs = top_policy_sections_commented(all_cities_dataframe, "all_common_comments", 4)
# Out:
# positive sentence: this is amazing. Very important.
# positive sentence: protected information
# positive sentence: That would be super helpful :)
# positive sentence: Awesome!
# positive sentence: Cheers for this!
# positive sentence: YES
# positive sentence: Datasets should also be analyzed and improved to be customer friendly.
# positive sentence: LOL
#
# total_comments: 164 ---- city name: All Cities
# None

# %% [markdown]
# ### method 2

# %%
#import nltk
from nltk.collocations import *
bigram_measures = nltk.collocations.BigramAssocMeasures()
trigram_measures = nltk.collocations.TrigramAssocMeasures()

# change this to read in your data
finder = TrigramCollocationFinder.from_words(words)

# only trigrams that appear 3+ times
finder.apply_freq_filter(4) 

# return the 10 n-grams with the highest PMI
print(finder.nbest(bigram_measures.pmi, 20))

#for k,v in finder.ngram_fd.items():
#  print(k,v)
# Out:
# [('data', 'governance', 'committee'), ('open', 'data', 'governance'), ('the', 'open', 'data')]
# ----------

# %% [markdown]
# # likes and replies analysis

# %% [markdown]
# ### comment analysis of comments with more than 2 *likes*

# %%
def likes_replies_analysis(count, option):
    high_likes = all_cities_dataframe[all_cities_dataframe[option] >= count]
    high_likes_comments = high_likes['comment_text']
    for high_like_comment in high_likes_comments:
        print()
        print("comment:")
        print()
        print(high_like_comment)

# %%
likes_replies_analysis("3", 'num_likes')
# Out:
# comment:
#
# I strongly support the proposed policy, with a recognition of the outstanding contributions that have already been made by other residents, citizens, and interested parties.Many thanks to the City of Buffalo for leading this effort. Most of my comments are within the document itself, but I do agree with other comments below that emphasize the need for substantial citizen involvement in governance, application, and oversight. During the RFP process, I would encourage the city to include not only requirements for a portal, but also an iterative feedback/improvement process with residents and regular data users so that the city's investment in this system can produce tangible use cases and real benefits to our city and its people.The Department of Citizen Services should also be commended for their use of the collaborative policymaking platform. In the age of the internet, this is an excellent way to increase public participation in these types of processes. Many thanks for this opportunity.
#
# comment:
#
# Thank you to the City of Buffalo!  My comments are regarding the geospatial (GIS) data. We often build tools for local government, and open data portals are our go-to standard to accessing data.  Please also consider including open access to live data such as webservices. Downloadable data, such as xmls, shapefiles or even file geodatabases are necessary for local processing and analysis.  However, most of our support to local government agencies is by functioning as tool and system developers. It makes us incredibly more productive (and accurate) to have access to live data.  I agree with Sean Meyers and support the distribution of the webservices and mapservices in web standard formats.  -Karyn Tareen CEO, Geocove
#
# comment:
#
# Thank you City of Buffalo for taking on this initiative. I have two comments:
#
# comment:
#
# My comments are rather lengthy. In addition to the comments below I've provided a copy inside a google doc. http://bit.ly/BuffaloOpenDataComments
#
# comment:
#
# Metadata is the key to making sure that the data is used correctly and enables the data to be used in as many different (yet appropriate) ways possible.
#
# comment:
#
# This document fails to require the sharing of the source code of the open data tools. "Require Code Sharing Or Publishing Open Source" is a recommendation of Sunlight Foundation https://sunlightfoundation.com/opendataguidelines/#open-code . Sharing the source code allows citizens to help contribute to the tools making the data public, allows citizens access to the tools for which they are paying, and allows other government agencies as well citizens to benefit from improvements made on behalf of Buffalo.
#
# comment:
#
# Some cities use an appointed board with members of the public and other stakeholders to provide support and recommendations to the CDO.
#
# comment:
#
# This is important, as the Chief Data officer will have first hand knowledge of what is working, and what isn't. This could be a good opportunity for the CDO to outline areas for improvement, and things that have not yet gone particularly well in the open data program.
#
# comment:
#
# Great idea. I would like to see how data is classified into private and public.

# %% [markdown]
# ### analysis of highly liked comments:
# - distribution of mapservices in web standard formats. Something for Arlington city government to take into account when making data public
# - there should be more citizen participation and engagement. How can Arlington make it happen?
# - Arlington should not stop the sharing of the source code of the open data tools.
# - classification of data into private and public? What does that mean?

# %% [markdown]
# ### comment analysis of comments with more than 2 *replies*

# %%
#all_cities_dataframe['reply_ids'].size
all_cities_dataframe['reply_ids_count'] = all_cities_dataframe['reply_ids'].str.len()

# %%
likes_replies_analysis(3, 'reply_ids_count')
# Out:
# comment:
#
# Other options being explored? Bulk dataset download is still very common and effective, especially for those users who may not be comfortable accessing an API.
#
# comment:
#
# Promote open data that informs increases in government efficiency, improvements in the quality of life of its citizens, and more equal opportunities for all residents.
#
# comment:
#
# Will data be shared if it is not regularly maintained?  Perhaps "date of update" could be identified in the metadata.  Will adopting an OpenData policy encourage the city to more regularly maintain datasets or will this clause be used to skirt sharing policies?  Historical data (not regularly maintained) is still data.
#
# comment:
#
# I am 100% supportive of open data and anything that improves citizen participation, however I opposed this document as it seems the Mayor implementing his own Open Data is a waste of funds and a duplication of efforts since this already exists for the City of Buffalo with the Comptroller's Open Book.  If the purpose of this document is to have one centralized location for citizens to access data, it seems the Mayor should work to promote the Open Book and any expansion of data be incorporated into that site.
#
# comment:
#
# is or will be
#
# comment:
#
# this is amazing. Very important.
#
# comment:
#
# A central location is a good idea, IMHO
#
# comment:
#
# I would recommend that it include members of the public with technical expertise and interest in publicly available data sets too instead of just receiving input.
#
# comment:
#
# I would hope the city uses GitHub for this task, instead of building a centralized location of it's own.
#
# comment:
#
# I usually think of "structured data" in opposition to "free text data." But I'd think that there are instances where you'd want to make "unstructured" data open, e.g., minutes from meetings or notes from an inspection.
#
# comment:
#
# Contradiction - Policies are not guidelines, IMO they are mandatory... guidelines are not mandatory
#
# comment:
#
# I believe we should be more agile & publish major accomplishments every quarter - waiting 1 year for a formal report of all blockers, issues, failures, and successes eliminates the very transparency the program is aiming to achieve
#
# comment:
#
# Given most modern web development relies on APIs and given that most APIs return JSON, a dataset in JSON would receive more interactions than an XML dataset.

# %% [markdown]
# ### analysis of highly replied to comments:
# - digital literacy since not every one knows how to use API.
# - periodically publishing accomplishments.
# - data quality and timely data?
# - asking for citizens' feedback/involving them in the process. What are the most important datasets that they want?

# %%
def name_tags(starting_url):
    soup = simple_crawl(starting_url)
    commentators = soup.findAll("li", class_="comment floating-card")    
    
    for comment in commentators:
        
        #------------finding names-------------#
        
        name_date = comment.find("div", class_="media-body media-middle")
        #print(type(names))
        #break
        
        #for name in names:
        #    print(name)
        
        name = name_date.find("span")
        #print(name.string.strip())
        
        #for name in names:
        
        #------------finding datetime-------------#
        
        time = name_date.find("time")
        time_update = time.get("datetime")[:-6]
        
        #time_update_1 = time_update.replace((/[A-Z]/), ' ')
        time_update_1 = time_update.replace("T", " ")
        #print(time_update_1)
         
        
        #------------finding comment_id-------------#
        
        #comment_id=comment.find("li").extract()
        comment_id=comment.get('id')
        #print(comment_id)
        
        #------------finding likes(if any)-------------#
        
        likes = name_date.find("span", class_="action-count")
        #print(likes.string.strip())
        
        #------------finding quoted comment-------------#
        
        comments = comment.find("div", class_="comment-content")
        quoted_comment = comments.find("blockquote")
        if quoted_comment is not None:
            quoted_comment_final = quoted_comment.text
            #print(quoted_comment_final)
    
        
        #------------finding actual comment-------------#
        comments = comment.find("div", class_="comment-content")
        #children = comments.children
        children = comments.find_all("p", recursive=False)
        #print(children)
        
        complete_str = ''
        
        for child in children:
            #print(child)
            complete_str += str(child)
        print("STR",complete_str)
            
        #number = 1
        
        #for actual_comment in children:
            #print("ACT " + str(number), actual_comment)
            
            #if len(actual_comment) > 1:
            #    print(actual_comment)
            #else:
                #print(actual_comment)
            #number += 1
        
        
        #for child in children:
        #    print(type(child))
            #actual_comment = child.string
            #print(actual_comment)
            
            #if actual_comment is not None:    
                #actual_comment_final = actual_comment
                #print(actual_comment_final)
                
                
        #------------finding reply(or replies') id(s)-------------#
        
        replies = comment.find_all("div", class_="comment")
        if replies is not None:
            for reply in replies:
                reply_id=reply.get('id')
                #print(reply_id)
        
    #------------finding the next page to crawl-------------#
    
    next_page = soup.find_all("ul", class_="pagination")
    
    
    for i in next_page:
        pages = i.find_all("a")
        #print(pages)
        #print(pages[-1].get("href"))
        
        num_pages = pages[-2].get("href")
        #print(num_pages[-1])

# %%
name_tags(starting_url)
